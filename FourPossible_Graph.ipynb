# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
# %matplotlib inline

# %%
auto = pd.read_csv("titanic.csv")
auto.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import matplotlib.pyplot as plt

# Create a histogram of ages
plt.figure(figsize=(10, 6))
plt.hist(auto['age'].dropna(), bins=30, edgecolor='black', color='green')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(x='pclass', data=auto, palette='YlGnBu') 
plt.title('Number of Passengers in Each Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_4028\3674534645.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='pclass', data=auto, palette='YlGnBu')

# %%
# Create a scatter plot comparing Age and Fare
plt.figure(figsize=(10, 6))
plt.bar(auto['age'], auto['fare'], alpha=0.5)
plt.title('Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)
plt.show()

# %%
colors = ['red', 'green', 'purple'] 
plt.figure(figsize=(10, 6))
sns.countplot(x='embarked', data=auto, palette=colors)
plt.title('Number of Passengers by Embarked Location')
plt.xlabel('Embarked Location')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_4028\3537835642.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='embarked', data=auto, palette=colors)
